# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %% [markdown]
# ## load training data

# %%
fname_data = 'assignment_08_data.csv'

data = np.genfromtxt(fname_data, delimiter=',')
num_data = data.shape[0]

point_x = np.zeros(num_data)
point_y = np.zeros(num_data)
label   = np.zeros(num_data)

for i in range(num_data):

    point_x[i]  = data[i,0]
    point_y[i]  = data[i,1]
    label[i]    = data[i,2]

point = np.array([[1]*num_data, point_x, point_y])

px0, py0, px1, py1 = [], [], [], []
for i in range(num_data):
    if label[i] == 0:
        px0.append(point_x[i])
        py0.append(point_y[i])
for i in range(num_data):
    if label[i] == 1:
        px1.append(point_x[i])
        py1.append(point_y[i])
px0 = np.array(px0)
py0 = np.array(py0)
px1 = np.array(px1)
py1 = np.array(py1)
# Out:
# (600,)

# %% [markdown]
# ## define linear regression function with inputs $\theta = (\theta_0, \theta_1, \theta_2)$ and ${\rm point} = (1, x, y)$

# %%
# f(x, y; theta)
def linear_regression(theta, point):
    
    value = theta.T @ point
    
    return value

# %% [markdown]
# ## define sigmoid function with input $x$

# %%
def sigmoid(x):

    z = 1 / (1+np.exp(-x))
    
    return z

# %% [markdown]
# ## define loss function for the logistic regression

# %%
# h = sigmoid (f)
def compute_loss(theta, point):
    
    wTx = linear_regression(theta, point)
    h = sigmoid(wTx)
    
    loss = -(1/num_data) * np.sum( label*np.log(h) + (np.full(num_data,1)-label)*np.log(np.full(num_data,1)-h) )
    
    return loss

# %% [markdown]
# ## define gradient vector for the model parameters $\theta = (\theta_0, \theta_1, \theta_2)$

# %%
def compute_gradient(theta, point, label):

    wTx = linear_regression(theta, point)
    h = sigmoid(wTx)
    ##
    # XT = np.array([[1]*num_data, x, y])
    # X = XT.T 
    # grad = (1/num_data) * XT@(X@theta - z)
    ##
    # point = np.array([[1]*num_data, point_x, point_y])
    ##
    
    #gradient = (1/num_data) * np.sum( xij * (h -label), axis=1 ) 
    gradient = (1/num_data) * point@(h-label)
    
    return gradient

# %% [markdown]
# ## gradient descent for the model parameters $\theta = (\theta_0, \theta_1, \theta_2)$

# %%
num_iteration   = 5000  # USE THIS VALUE for the number of gradient descent iterations 
learning_rate   = 0.001 # USE THIS VALUE for the learning rate
theta           = np.array((0, 0, 0))   # USE THIS VALUE for the initial condition of the model parameters

# %% [markdown]
# ## iterations for the gradient descent

# %%
theta_iteration = np.zeros((num_iteration, theta.size))
loss_iteration  = np.zeros(num_iteration)

for i in range(num_iteration):
    
    theta = theta - learning_rate * compute_gradient(theta, point, label)
    loss = compute_loss(theta, point)
    
    theta_iteration[i] = theta
    loss_iteration[i] = loss
    
    print("iteration = %4d, loss = %5.5f" % (i, loss))
# Out:
# iteration =    0, loss = 0.66813
# iteration =    1, loss = 0.64476
# iteration =    2, loss = 0.62295
# iteration =    3, loss = 0.60256
# iteration =    4, loss = 0.58350
# iteration =    5, loss = 0.56567
# iteration =    6, loss = 0.54897
# iteration =    7, loss = 0.53332
# iteration =    8, loss = 0.51864
# iteration =    9, loss = 0.50485
# iteration =   10, loss = 0.49188
# iteration =   11, loss = 0.47967
# iteration =   12, loss = 0.46817
# iteration =   13, loss = 0.45731
# iteration =   14, loss = 0.44706
# iteration =   15, loss = 0.43736
# iteration =   16, loss = 0.42817
# iteration =   17, loss = 0.41947
# iteration =   18, loss = 0.41121
# iteration =   19, loss = 0.40336
# iteration =   20, loss = 0.39590
# iteration =   21, loss = 0.38879
# iteration =   22, loss = 0.38202
# iteration =   23, loss = 0.37557
# iteration =   24, loss = 0.36940
# iteration =   25, loss = 0.36351
# iteration =   26, loss = 0.35787
# iteration =   27, loss = 0.35248
# ...

# %%
f = theta[0] + theta[1] * point_x + theta[2] * point_y

# %% [markdown]
# ## plot the results

# %%
num = np.arange(num_iteration)
def plot_loss_curve(loss_iteration):

    plt.figure(figsize=(8,6))   
    plt.title('loss')

    plt.plot(num, loss_iteration, '-', color = 'red')

    plt.xlabel('iteration')
    plt.ylabel('loss')

    plt.tight_layout()
    plt.show()

# %%
def plot_data(point_x, point_y, label):
    
    plt.figure(figsize=(8,8))

    plt.title('training data')
    
    plt.scatter(px0, py0, marker='o', c='blue', label='class 0')
    plt.scatter(px1, py1, marker='o', c='red', label='class 1')
    
    plt.legend()
    
    plt.axis('equal')
    
    plt.tight_layout()
    plt.show()

# %%
def plot_model_parameter(theta_iteration):

    plt.figure(figsize=(8,6))
    plt.title('model parameter')

    plt.xlabel('iteration')
    
    plt.plot(num, theta_iteration[:,0], '-', color = 'red', label = 'theta0')
    plt.plot(num, theta_iteration[:,1], '-', color = 'green', label = 'theta1')
    plt.plot(num, theta_iteration[:,2], '-', color = 'blue', label = 'theta2')
    
    plt.legend(loc = 'center right')
    
    plt.tight_layout()
    plt.show()

# %%
def plot_classifier(point_x, point_y, label, f):


    plt.scatter(px0, py0, marker='o', c='blue', label='class 0')
    plt.scatter(px1, py1, marker='o', c='red', label='class 1')
    
    plt.plot(point_x, f, '-', color = 'black')
    plt.axis('equal')
    
    
    plt.colorbar()
    #ax.set_facecolor('coolwarm')
    plt.pcolormesh([point_x, point_y], f,cmap="coolwarm")
    
    plt.legend()
    
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *

# %% [markdown]
# # * results

# %% [markdown]
# # * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *

# %% [markdown]
# ### # 01. plot the input data point in blue for class 0 and in red for class 1

# %%
plot_data(point_x, point_y, label)

# %% [markdown]
# ### # 02. plot the values of the model parameters $\theta_0$ in red curve, $\theta_1$ in green curve, and $\theta_2$ in blue curve over the gradient descent iterations

# %%
plot_model_parameter(theta_iteration)

# %% [markdown]
# ### # 03. plot the loss values $\mathcal{L}(\theta)$ in red curve over the gradient descent iterations

# %%
plot_loss_curve(loss_iteration)

# %% [markdown]
# ### # 04. plot the classifier with the given data points superimposed

# %%
plot_classifier(point_x, point_y, label, f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-4ee877cc8c81> in <module>
# ----> 1 plot_classifier(point_x, point_y, label, f)
#
# <ipython-input-97-0ab28f5522a4> in plot_classifier(point_x, point_y, label, f)
#      11     plt.colorbar()
#      12     #ax.set_facecolor('coolwarm')
# ---> 13     plt.pcolormesh([point_x, point_y], f,cmap="coolwarm")
#      14
#      15     plt.legend()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2720         vmax=None, shading='flat', antialiased=False, data=None,
#    2721         **kwargs):
# -> 2722     __ret = gca().pcolormesh(
#    2723         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2724         vmax=vmax, shading=shading, antialiased=antialiased,
#
# ...
